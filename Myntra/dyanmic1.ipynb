# %% [markdown]
# <div style="
#     background: linear-gradient(to right, #ff9a9e, #fad0c4);
#     padding: 40px;
#     text-align: center;
#     border-radius: 15px;
#     box-shadow: 0 8px 20px rgba(0,0,0,0.2);
#     font-family: Helvetica, sans-serif;
# ">
#
# <h1 style="color: #2d2d2d; margin-bottom: 15px; font-size: 38px;">
#         🛍️ Myntra Dynamic Web Scraping
#     </h1>
#
#  <p style="color: #444; font-style: italic; font-size: 18px; margin-bottom: 20px;">
#         Extracting Product Names Using Selenium
#     </p>
#
#  <p style="
#         background-color: white;
#         display: inline-block;
#         padding: 10px 25px;
#         border-radius: 25px;
#         font-weight: bold;
#         font-size: 18px;
#         color: #6a11cb;
#         box-shadow: 0 4px 10px rgba(0,0,0,0.1);
#     ">
#         Mansi Sharma
#     </p>
#
# </div>

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://www.myntra.com/shoes")
time.sleep(5) 

products = driver.find_elements(By.CLASS_NAME, "product-base")
data_list = []

for item in products:

    name = item.find_element(By.CLASS_NAME, "product-product").text
    price = item.find_element(By.CLASS_NAME, "product-price").text
    
    data_list.append({"Product Name": name, "Price": price})

driver.quit()

df = pd.DataFrame(data_list)
df
# Out:
#                           Product Name                           Price
# 0          3 Next Nature Workout Shoes       Rs. 3996Rs. 4995(20% OFF)
# 1          3 Next Nature Workout Shoes       Rs. 3996Rs. 4995(20% OFF)
# 2           Textured Party Block Pumps        Rs. 699Rs. 2999(77% OFF)
# 3          Unisex Back To School Shoes   Rs. 924Rs. 3699(Rs. 2775 OFF)
# 4           Girls Round Toe Ballerinas        Rs. 899Rs. 2499(64% OFF)
# 5                  Women Running Shoes   Rs. 987Rs. 3799(Rs. 2812 OFF)
# 6             HRX-235 01 Running Shoes   Rs. 879Rs. 3999(Rs. 3120 OFF)
# 7        Men Colourblocked PU Sneakers       Rs. 1291Rs. 6799(81% OFF)
# 8         Round Toe Slip-On Ballerinas                         Rs. 999
# 9   Unisex Kids Colourblocked Sneakers        Rs. 443Rs. 1299(66% OFF)
# 10            Men CLOUDFOAM GO LOUNGER       Rs. 3359Rs. 5999(44% OFF)
# 11                   Men Running Shoes       Rs. 1154Rs. 3299(65% OFF)
# 12       Girls Frozen Printed Sneakers        Rs. 463Rs. 1799(74% OFF)
# 13              Boys Round Toe Loafers        Rs. 969Rs. 2999(68% OFF)
# 14                    Women Ballerinas       Rs. 1499Rs. 2499(40% OFF)
# 15             Party Slim Heeled Pumps        Rs. 999Rs. 2999(67% OFF)
# 16           Women Mavin Court Sneaker       Rs. 1993Rs. 4999(60% OFF)
# 17           Girls Block Heels Sandals        Rs. 561Rs. 1299(57% OFF)
# 18         Girls Embellished Mary Jane        Rs. 749Rs. 3099(76% OFF)
# 19                   Men Running Shoes       Rs. 2799Rs. 4069(31% OFF)
# 20                   Men Formal Derbys        Rs. 747Rs. 1099(32% OFF)
# 21            Men Active Running Shoes  Rs. 1399Rs. 6999(Rs. 5600 OFF)
# 22            Men Running Sports Shoes       Rs. 1576Rs. 8299(81% OFF)
# 23          Girls Textured PU Sneakers                        Rs. 1299
# 24         Kids Colourblocked Sneakers        Rs. 361Rs. 2000(82% OFF)
# 25                  Road-Running Shoes                        Rs. 3995
# 26            Men Active Running Shoes  Rs. 1329Rs. 6999(Rs. 5670 OFF)
# 27             Women Ballet Ballerinas       Rs. 1319Rs. 2199(40% OFF)
# 28                 Women Running Shoes       Rs. 2619Rs. 4699(44% OFF)
# 29                   Men Running Shoes       Rs. 1742Rs. 8299(79% OFF)
# 30           Kitten Mules with Buckles        Rs. 999Rs. 2999(67% OFF)
# 31              Run Defy Running Shoes                        Rs. 3995
# 32                 Women Running Shoes       Rs. 3499Rs. 6999(50% OFF)
# 33        Skyrocket Lite Running Shoes       Rs. 2849Rs. 4999(43% OFF)
# 34             Men Strada Vele Sneaker       Rs. 1436Rs. 2624(45% OFF)
# 35          Square Open Toe Ballerinas       Rs. 1199Rs. 2399(50% OFF)
# 36             Girls Closed Back Pumps        Rs. 893Rs. 1599(44% OFF)
# 37           Men Perforations Sneakers         Rs. 636Rs. 749(15% OFF)
# 38        Round Toe Slip-On Ballerinas                         Rs. 999
# 39                   Men Running Shoes   Rs. 959Rs. 3999(Rs. 3040 OFF)
# 40          Men Colourblocked Sneakers       Rs. 1359Rs. 6799(80% OFF)
# 41         Textured Block-Heeled Boots  Rs. 1602Rs. 3956(Rs. 2354 OFF)
# 42           Women Embellished Mojaris       Rs. 1183Rs. 3699(68% OFF)
# 43          Jiro Black Mary Jane Flats       Rs. 1791Rs. 1990(10% OFF)
# 44                                       Rs. 713Rs. 2499(Rs. 1786 OFF)
# 45                   Men Walking Shoes        Rs. 831Rs. 2999(72% OFF)
# 46      Softride Frequence Street Shoe       Rs. 3499Rs. 6999(50% OFF)
# 47           Men Leather Formal Derbys   Rs. 659Rs. 3299(Rs. 2640 OFF)
# 48         Pointed Toe Slingback Flats        Rs. 389Rs. 1499(74% OFF)
# 49             Round Toe Formal Derbys   Rs. 999Rs. 4999(Rs. 4000 OFF)

# %% [markdown]
# <html>
# <head>
#     <title></title>
# </head>
# <body
# style="background: linear-gradient(to right, #74ebd5, #ACB6E5);
#     text-align: center;
#              font-family: Arial;
#              margin: 0;
#              padding-top: 150px;">
#
# <div style="background-color: white;
#                 display: inline-block;
#                 padding: 40px 60px;
#                 border-radius: 15px;
#                 box-shadow: 0 8px 20px rgba(0,0,0,0.2);">
#
#   <h1 style="color: #2c3e50; font-size: 42px; margin-bottom: 10px;">
#             Thank You!
#         </h1>
#
# <p style="font-size: 22px; color: #6c5ce7; font-weight: bold;">
#             Mansi Sharma
#         </p>
#
#   </div>
#
# </body>
# </html>
