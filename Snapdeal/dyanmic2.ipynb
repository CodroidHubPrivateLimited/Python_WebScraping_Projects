# %% [markdown]
# <hr style="border: 1px solid #e40046; margin-top: 10px;">
# <div style="
#     background: linear-gradient(to right, #ff9a9e, #fad0c4);
#     padding: 40px;
#     text-align: center;
#     border-radius: 15px;
#     box-shadow: 0 8px 20px rgba(0,0,0,0.2);
#     font-family: Helvetica, sans-serif;
# ">
#
# <h1 style="color: #2d2d2d; margin-bottom: 15px; font-size: 38px;">
#         🛍️ Snapdeal dyanmic web Scraping
#     </h1>
#
#  <p style="color: #444; font-style: italic; font-size: 18px; margin-bottom: 20px;">
#         Extracting Product Names and price Using Selenium
#     </p>
#
#  <p style="
#         background-color: white;
#         display: inline-block;
#         padding: 10px 25px;
#         border-radius: 25px;
#         font-weight: bold;
#         font-size: 18px;
#         color: #6a11cb;
#         box-shadow: 0 4px 10px rgba(0,0,0,0.1);
#     ">
#         Mansi Sharma
#     </p>
#
# </div>

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://www.snapdeal.com/search?keyword=tshirt")
time.sleep(5) 

products = driver.find_elements(By.CLASS_NAME, "product-tuple-listing")
data_list = []

for item in products:
    name = item.find_element(By.CLASS_NAME, "product-title").text
    price = item.find_element(By.CLASS_NAME, "product-price").text
    
    data_list.append({"Name": name, "Price": price})

driver.quit()

df = pd.DataFrame(data_list)
display(df)
# Out:
#                                                  Name    Price
# 0   FTX Men Polyester Regular Fit Solid T-Shirt ( ...  Rs. 232
# 1   AUSK Men Cotton Blend Regular Fit Striped Polo...  Rs. 391
# 2   FABRIPPLE Polyester Regular Fit Printed Full S...  Rs. 243
# 3   TREND SKY Pack of 2 Polyester Regular Fit Men'...  Rs. 299
# 4   Alexender Cotton Regular Fit Printed Full Slee...  Rs. 221
# 5   ENITOR Men Cotton Blend Oversized Fit Printed ...  Rs. 287
# 6   AUSK Men Cotton Blend Regular Fit Printed T-Sh...  Rs. 386
# 7   Alexender Cotton Regular Fit Solid Full Sleeve...  Rs. 215
# 8   MD By Mathra Dass Men Cotton Blend Regular Fit...  Rs. 289
# 9   AUSK Hooded T-Shirt for Men - Cotton Blend ( M...  Rs. 336
# 10  Harshtaruhub Men Cotton Blend Regular Fit Prin...  Rs. 262
# 11  LEWEL Cotton Blend Oversized Fit Printed 3/4th...  Rs. 287
# 12  Deslizar Cotton Blend Oversized Fit Printed Ha...  Rs. 282
# 13  lookswala Multicolor Polyester Regular Fit Men...  Rs. 382
# 14  Try This Pack of 1 Cotton Blend Regular Fit Me...  Rs. 382
# 15  connan Cotton Regular Fit Dyed Half Sleeves Me...  Rs. 282
# 16  NB NICKY BOY Pack of 1 Cotton Blend Regular Fi...  Rs. 282
# 17  TrendsTalk Men Polyester Regular Fit Printed P...  Rs. 312
# 18  LEWEL Cotton Blend Oversized Fit Printed 3/4th...  Rs. 287
# 19  ekadravin Cotton Oversized Fit Printed Half Sl...  Rs. 251

# %% [markdown]
# <html>
# <head>
#     <title></title>
# </head>
# <body
# style="background: linear-gradient(to right, #74ebd5, #ACB6E5);
#     text-align: center;
#              font-family: Arial;
#              margin: 0;
#              padding-top: 150px;">
#
# <div style="background-color: white;
#                 display: inline-block;
#                 padding: 40px 60px;
#                 border-radius: 15px;
#                 box-shadow: 0 8px 20px rgba(0,0,0,0.2);">
#
#   <h1 style="color: #2c3e50; font-size: 42px; margin-bottom: 10px;">
#             Thank You!
#         </h1>
#
# <p style="font-size: 22px; color: #6c5ce7; font-weight: bold;">
#             Mansi Sharma
#         </p>
#
#   </div>
#
# </body>
# </html>
