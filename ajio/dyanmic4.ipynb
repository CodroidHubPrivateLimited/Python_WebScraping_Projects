# %% [markdown]
# <div style="
#     background: linear-gradient(to right, #ff9a9e, #fad0c4);
#     padding: 40px;
#     text-align: center;
#     border-radius: 15px;
#     box-shadow: 0 8px 20px rgba(0,0,0,0.2);
#     font-family: Helvetica, sans-serif;
# ">
#
# <h1 style="color: #2d2d2d; margin-bottom: 15px; font-size: 38px;">
#         🛍️ ajio Web Scraping
#     </h1>
#
#  <p style="color: #444; font-style: italic; font-size: 18px; margin-bottom: 20px;">
#         Extracting Product Brand ,Names and price Using Selenium
#     </p>
#
#  <p style="
#         background-color: white;
#         display: inline-block;
#         padding: 10px 25px;
#         border-radius: 25px;
#         font-weight: bold;
#         font-size: 18px;
#         color: #6a11cb;
#         box-shadow: 0 4px 10px rgba(0,0,0,0.1);
#     ">
#         Mansi Sharma
#     </p>
#
# </div>

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
url = "https://www.ajio.com/s/underrs399-120271"
driver.get(url)
time.sleep(5) 


products = driver.find_elements(By.CLASS_NAME, "item")
data_list = []

for item in products:

    brand = item.find_element(By.CLASS_NAME, "brand").text
    name = item.find_element(By.CLASS_NAME, "nameCls").text
    price = item.find_element(By.CLASS_NAME, "price").text
    
    data_list.append({
        "Brand": brand,
        "Product Name": name,
        "Price": price
    })

driver.quit()

df = pd.DataFrame(data_list)
df
# Out:
#                   Brand                                       Product Name  \
# 0        KB TEAM SPIRIT                      Boys Relaxed Fit Jogger Pants
# 1   AVAASA MIX N' MATCH       Ankle-Length Leggings with Elasticated Waist
# 2   AVAASA MIX N' MATCH       Ankle-Length Leggings with Elasticated Waist
# 3               YB DNMX        Boys Mid-Rise Joggers with Drawstring Waist
# 4               YB DNMX                 Boys Joggers with Drawstring Waist
# 5            Teamspirit       Women Striped Regular Fit Round-Neck T-Shirt
# 6                   RIO             Women Star Print T-Shirt & Pyjamas Set
# 7            INF FRENDZ       Girls Schiffli Embroidered Fit & Flare Dress
# 8            Teamspirit       Women Striped Regular Fit Round-Neck T-Shirt
# 9         HAUTE & SPICY                  Dual-Strap Sandals with Slingback
# 10            PERFORMAX                  Men Mid-Rise Straight Track Pants
# ...

# %% [markdown]
# <html>
# <head>
#     <title></title>
# </head>
# <body
# style="background: linear-gradient(to right, #74ebd5, #ACB6E5);
#     text-align: center;
#              font-family: Arial;
#              margin: 0;
#              padding-top: 150px;">
#
# <div style="background-color: white;
#                 display: inline-block;
#                 padding: 40px 60px;
#                 border-radius: 15px;
#                 box-shadow: 0 8px 20px rgba(0,0,0,0.2);">
#
#   <h1 style="color: #2c3e50; font-size: 42px; margin-bottom: 10px;">
#             Thank You!
#         </h1>
#
# <p style="font-size: 22px; color: #6c5ce7; font-weight: bold;">
#             Mansi Sharma
#         </p>
#
#   </div>
#
# </body>
# </html>
