# %% [markdown]
# <div style="text-align: center; padding: 20px:colour='red'">
#     <h1 style="color: rgb(249, 249, 246);">Vishal Sachdeva</h1>
#     <h2 style="color: rgb(251, 255, 9);">Blinkit Dynamic</h2>
#     <p style="font-size: 16px; max-width: 700px; margin: auto;">
#         faching the data from the blinkit website
#     </p>
#     <hr style="width: 60%;">
# </div>

# %%
# !pip install selenium
# Out:
# ...
#   Using cached selenium-4.40.0-py3-none-any.whl.metadata (7.7 kB)
# ...
#   Using cached certifi-2026.1.4-py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached trio_typing-0.10.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached types_certifi-2021.10.8.3-py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached types_urllib3-1.26.25.14-py3-none-any.whl.metadata (1.7 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached async_generator-1.10-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached wsproto-1.3.2-py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# ...
# Using cached selenium-4.40.0-py3-none-any.whl (9.6 MB)
# ...

# %%
# !pip install webdriver_manager
# Out:
# ...
#   Using cached webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# ...
# Using cached webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://blinkit.com/cn/chips-crisps/cid/1237/940")
time.sleep(2)
quotes = driver.find_elements(By.CSS_SELECTOR, "div[role='button']")
for quote in quotes:
    print(quote.text)
    
driver.quit()
# Out:
# Chips & Crisps
# Rusks & Wafers
# Energy Bars
# Nachos
# Bhujia & Mixtures
# Popcorn
# Namkeen Snacks
# Makhana & More
# Papad & Fryums
# Imported Snacks
# Granola
# Munchies Gift Packs
# 8 MINS
# Sweet Karam Coffee Andhra Spicy Murukku
# 95 g
# ₹90
# ₹92
# ADD
# 3 options
# ADD
# 3 options
# 8 MINS
# Kettle Studio Rock Sea Salt & English Vinegar Potato Chips
# 113 g
# ₹99
# ADD
# ADD
# 8 MINS
# Protein Chef Baked Coated Peanuts (Masala Roasted Healthy Snacks)
# 50 g
# ₹69
# ₹70
# ADD
# 2 options
# ADD
# 2 options
# 8 MINS
# Kurkure Masala Munch Crisps
# 75 g
# ₹20
# ADD
# 2 options
# ADD
# 2 options
# 43% OFF
# 20 MINS
# NUTS & ROOTS Beetroot Chips
# 4 packs
# ₹249
# ₹440
# ADD
# ADD
# 8 MINS
# Kettle Studio Sharp Jalapenos & Cream Cheese Potato Chips
# 113 g
# ₹99
# ADD
# 2 options
# ADD
# 2 options
# 8 MINS
# Kettle Studio Potato Chips - Himalyan Pink Salt
# 113 g
# ₹99
# ADD
# ADD
# 8 MINS
# Kettle Studio Sweet Chilli With Lime & Basil Potato Chips
# 60 g
# ₹49
# ADD
# 2 options
# ...

# %%
quote_list=[]
for q in quotes:
    quote_list.append(q.text)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:204, in HTTPConnection._new_conn(self)
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ...

# %%
quote_list

# %% [markdown]
# <marquee><h2 style="color: yellow;">Thanku</h2></marquee>>
