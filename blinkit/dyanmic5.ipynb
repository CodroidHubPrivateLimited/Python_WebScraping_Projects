# %% [markdown]
# <div style="
#     background: linear-gradient(to right, #ff9a9e, #fad0c4);
#     padding: 40px;
#     text-align: center;
#     border-radius: 15px;
#     box-shadow: 0 8px 20px rgba(0,0,0,0.2);
#     font-family: Helvetica, sans-serif;
# ">
#
# <h1 style="color: #2d2d2d; margin-bottom: 15px; font-size: 38px;">
#         🛍️ Blinkit Web Scraping
#     </h1>
#
#  <p style="color: #444; font-style: italic; font-size: 18px; margin-bottom: 20px;">
#         Extracting Product info Using Selenium
#     </p>
#
#
#  <p style="
#         background-color: white;
#         display: inline-block;
#         padding: 10px 25px;
#         border-radius: 25px;
#         font-weight: bold;
#         font-size: 18px;
#         color: #6a11cb;
#         box-shadow: 0 4px 10px rgba(0,0,0,0.1);
#     ">
#         Mansi Sharma
#     </p>
#
# </div>

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

driver.get("https://blinkit.com/cn/appliances/cid/1379/1886")
time.sleep(5)

elements = driver.find_elements(By.CSS_SELECTOR, "div[role='button']")

data = []

for element in elements:
    text = element.text.strip()
    if text:   
        data.append(text)

driver.quit()

df = pd.DataFrame(data, columns=["Product Info"])
df
# Out:
#                                          Product Info
# 0                         Spiritual & Religious Needs
# 1                                    Party Essentials
# 2                                          Home Decor
# 3                            Festive & Occasion Needs
# 4                               Tissues & Disposables
# ..                                                ...
# 67                                                ADD
# 68  40% OFF\n10 MINS\nAgaro Royal Electric Recharg...
# 69                                                ADD
# 70  40% OFF\n10 MINS\nDr Trust Nano Ionic Facial S...
# 71                                                ADD
#
# [72 rows x 1 columns]

# %% [markdown]
# <html>
# <head>
#     <title></title>
# </head>
# <body
# style="background: linear-gradient(to right, #74ebd5, #ACB6E5);
#     text-align: center;
#              font-family: Arial;
#              margin: 0;
#              padding-top: 150px;">
#
# <div style="background-color: white;
#                 display: inline-block;
#                 padding: 40px 60px;
#                 border-radius: 15px;
#                 box-shadow: 0 8px 20px rgba(0,0,0,0.2);">
#
#   <h1 style="color: #2c3e50; font-size: 42px; margin-bottom: 10px;">
#             Thank You!
#         </h1>
#
# <p style="font-size: 22px; color: #6c5ce7; font-weight: bold;">
#             Mansi Sharma
#         </p>
#
#   </div>
#
# </body>
# </html>
