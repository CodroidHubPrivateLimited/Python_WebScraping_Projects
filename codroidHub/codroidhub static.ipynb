# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title></title>
# </head>
#
# <body style="margin:0; padding:0; font-family: Arial, sans-serif; background-color:#e3f2fd;">
#
# <div style="
#     max-width: 800px;
#     margin: 100px auto;
#     padding: 40px;
#     background-color: white;
#     border-radius: 15px;
#     box-shadow: 0 10px 25px rgba(0,0,0,0.2);
#     text-align: center;
# ">
#
# <h1 style="color: #232f3e; margin-bottom: 15px;">
#      Codroidhub Website Scraping
# </h1>
#
#
#
# <h4 style="color: #555; font-weight: normal;">
#     🛠️ Tools Used: Requests | BeautifulSoup | Pandas
# </h4>
#
# </div>
#
# </body>
# </html>

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url="https://puirf.codroidhub.com/api/api/v1/instruments/user/getHomeFacilities"
headers={
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36" 
}
response = requests.get(url, headers = headers)
print(response)
print(response.content)
data = response.json()
# Out:
# <Response [200]>
# b'{"success":true,"data":{"saif":[{"_id":"6926be1c3435e9dc23507531","name":"FT NMR","uniqueId":"NMR","upcomingInstrument":false,"images":["/instruments/NMR/IMG_20260114_145734.jpg"]},{"_id":"6926bf853435e9dc23507571","name":"MALDI TOF SYNAPT XS HD MASS SPECTROMETER","uniqueId":"LCMS","upcomingInstrument":false,"images":["/instruments/LCMS/IMG_20260114_144508.jpg"]},{"_id":"6926c65f3435e9dc23507655","name":"X ray Photon Spectroscopy","uniqueId":"XPS","upcomingInstrument":false,"images":["/instruments/XPS/IMG_20260114_145053.jpg"]},{"_id":"6926c2ac3435e9dc235075fa","name":"X Ray Diffraction","uniqueId":"XRD","upcomingInstrument":false,"images":["/instruments/XRD/IMG_20260114_134412.jpg"]},{"_id":"6926bca63435e9dc2350751b","name":"Field Emission Scanning Electron Microscopy","uniqueId":"FE-SEM","upcomingInstrument":false,"images":["/instruments/FE-SEM/IMG_20260114_161728.jpg"]},{"_id":"6926c70f3435e9dc23507689","name":"SCANNING ELECTRON MICROSCOPY","uniqueId":"SEM","upcomingInstrument":false,"images":["/instruments/SEM/IMG_20260114_150644.jpg"]},{"_id":"6926c4043435e9dc23507624","name":"INDUCTIVELY COUPLED PLASMA MASS SPECTROMETRY","uniqueId":"ICPMS","upcomingInstrument":false,"images":["/instruments/ICPMS/IMG_20260114_170342.jpg"]},{"_id":"6926c89f3435e9dc235076f6","name":"THERMO GRAVIMETRIC ANALYSIS","uniqueId":"TGA","upcomingInstrument":false,"images":["/instruments/TGA/IMG_20260114_151749.jpg"]},{"_id":"6926cab53435e9dc2350775f","name":"DSC","uniqueId":"DSC","upcomingInstrument":false,"images":["/instruments/DSC/IMG_20260114_151625.jpg"]},{"_id":"6926c7b63435e9dc235076c4","name":"BET ANALYZER","uniqueId":"BET","upcomingInstrument":false,"images":["/instruments/BET/IMG_20260114_145345.jpg"]},{"_id":"6926df1e3df7cf0198802cc2","name":"Fluorescence","uniqueId":"FLURO","upcomingInstrument":false,"images":["/instruments/FLURO/IMG_20260114_152449.jpg"]},{"_id":"6926e0603df7cf0198802d0b","name":"CD Spectrometer","uniqueId":"CD","upcomingInstrument":false,"images":["/instruments/CD/IMG_20260114_151256.jpg"]},{"_id":"6926e46d3df7cf019880303c","name":"UV VIS","uniqueId":"UV-VIS","upcomingInstrument":false,"images":["/instruments/UV-VIS/IMG_20260114_152435.jpg"]},{"_id":"6926e1c83df7cf0198802e3e","name":"ELLIPSOMETER","uniqueId":"ELLIPSOMETER","upcomingInstrument":false,"images":["/instruments/ELLIPSOMETER/IMG_20260114_152959.jpg"]},{"_id":"6926e3593df7cf0198802f91","name":"POLARIMETER","uniqueId":"POLARIMETER","upcomingInstrument":false,"images":["/instruments/POLARIMETER/Productpage_Gallery_2400x1600_MCP_4100_5100_5500_01-600x400.jpg"]},{"_id":"6926e1183df7cf0198802df2","name":"LIQUID NITROGEN","uniqueId":"LN2","upcomingInstrument":false,"images":["/instruments/LN2/liquid-nitrogen-generator-250x250.png"]},{"_id":"6926e27d3df7cf0198802ee6","name":"Critical point dryer","uniqueId":"Critical point dryer","upcomingInstrument":false,"images":["/instruments/Critical point dryer/leica-em-cpd300-critical-point-dryer.jpg"]},{"_id":"6926e5483df7cf0198803136","name":"ULTRA MICROTOME","uniqueId":"ULTRA MICROTOME","upcomingInstrument":false,"images":["/instruments/ULTRA MICROTOME/uc6.jpg"]},{"_id":"6926de8a3df7cf0198802bea","name":"ZETA ANALYZER","uniqueId":"Zeta","upcomingInstrument":false,"images":["/instruments/Zeta/IMG_20260114_152004.jpg"]}],"cil":[{"_id":"6926da753df7cf0198802a41","name":"HIGH RESOLUTION TRANSMISSION ELECTRON MICROSCOPY","uniqueId":"HRTEM","upcomingInstrument":false,"images":["/instruments/HRTEM/IMG_20260114_161204.jpg"]},{"_id":"6926db8d3df7cf0198802ad5","name":"Gas Chromatography Mass Spectrometry","uniqueId":"GCMS","upcomingInstrument":false,"images":["/instruments/GCMS/IMG_20260114_153245.jpg"]},{"_id":"6926d8f53df7cf0198802a06","name":"Confocal microscopy","uniqueId":"Confocal","upcomingInstrument":false,"images":["/instruments/Confocal/IMG_20260114_152137.jpg"]},{"_id":"6926cc043435e9dc235077e2","name":"Small Angle X ray Scattering","uniqueId":"SAXS","upcomingInstrument":false,"images":["/instruments/SAXS/IMG_20260114_1 ...

# %%
print(data["data"])
main_data= data["data"]
main_data.keys()
saif_data = main_data["saif"]
print(len(saif_data))
cil_data = main_data["cil"]
name_list = []
unique_id_list = []

for saif in saif_data:
    # print(saif)
    name_list.append(saif["name"])
    unique_id_list.append(saif["uniqueId"])
    
df = pd.DataFrame({
    "Name": name_list,
    "Unique_Id": unique_id_list
})
df
# Out:
strument': False, 'images': ['/instruments/LN2/liquid-nitrogen-generator-250x250.png']}, {'_id': '6926e27d3df7cf0198802ee6', 'name': 'Critical point dryer', 'uniqueId': 'Critical point dryer', 'upcomingInstrument': False, 'images': ['/instruments/Critical point dryer/leica-em-cpd300-critical-point-dryer.jpg']}, {'_id': '6926e5483df7cf0198803136', 'name': 'ULTRA MICROTOME', 'uniqueId': 'ULTRA MICROTOME', 'upcomingInstrument': False, 'images': ['/instruments/ULTRA MICROTOME/uc6.jpg']}, {'_id': '6926de8a3df7cf0198802bea', 'name': 'ZETA ANALYZER', 'uniqueId': 'Zeta', 'upcomingInstrument': False, 'images': ['/instruments/Zeta/IMG_20260114_152004.jpg']}], 'cil': [{'_id': '6926da753df7cf0198802a41', 'name': 'HIGH RESOLUTION TRANSMISSION ELECTRON MICROSCOPY', 'uniqueId': 'HRTEM', 'upcomingInstrument': False, 'images': ['/instruments/HRTEM/IMG_20260114_161204.jpg']}, {'_id': '6926db8d3df7cf0198802ad5', 'name': 'Gas Chromatography Mass Spectrometry', 'uniqueId': 'GCMS', 'upcomingInstrument': False, 'images': ['/instruments/GCMS/IMG_20260114_153245.jpg']}, {'_id': '6926d8f53df7cf0198802a06', 'name': 'Confocal microscopy', 'uniqueId': 'Confocal', 'upcomingInstrument': False, 'images': ['/instruments/ ...
# 19
#                                             Name             Unique_Id
# 0                                         FT NMR                   NMR
# 1       MALDI TOF SYNAPT XS HD MASS SPECTROMETER                  LCMS
# 2                      X ray Photon Spectroscopy                   XPS
# 3                              X Ray Diffraction                   XRD
# 4    Field Emission Scanning Electron Microscopy                FE-SEM
# 5                   SCANNING ELECTRON MICROSCOPY                   SEM
# 6   INDUCTIVELY COUPLED PLASMA MASS SPECTROMETRY                 ICPMS
# 7                    THERMO GRAVIMETRIC ANALYSIS                   TGA
# 8                                            DSC                   DSC
# 9                                   BET ANALYZER                   BET
# 10                                  Fluorescence                 FLURO
# 11                               CD Spectrometer                    CD
# 12                                        UV VIS                UV-VIS
# 13                                  ELLIPSOMETER          ELLIPSOMETER
# 14                                   POLARIMETER           POLARIMETER
# 15                               LIQUID NITROGEN                   LN2
# 16                          Critical point dryer  Critical point dryer
# 17                               ULTRA MICROTOME       ULTRA MICROTOME
# 18                                 ZETA ANALYZER                  Zeta

# %% [markdown]
# <html>
# <head>
#     <title></title>
# </head>
# <body
# style="background: linear-gradient(to right, #74ebd5, #ACB6E5);
#     text-align: center;
#              font-family: Arial;
#              margin: 0;
#              padding-top: 150px;">
#
# <div style="background-color: white;
#                 display: inline-block;
#                 padding: 40px 60px;
#                 border-radius: 15px;
#                 box-shadow: 0 8px 20px rgba(0,0,0,0.2);">
#
#   <h1 style="color: #2c3e50; font-size: 42px; margin-bottom: 10px;">
#             Thank You!
#         </h1>
#
# <p style="font-size: 22px; color: #6c5ce7; font-weight: bold;">
#             Mansi Sharma
#         </p>
#
#   </div>
#
# </body>
# </html>
