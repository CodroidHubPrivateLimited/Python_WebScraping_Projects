# %% [markdown]
# <div style="text-align: center; padding: 20px:colour='red'">
#     <h1 style="color: rgb(246, 253, 253);">Vishal Sachdeva</h1>
#     <h2 style="color: rgb(7,253,253);">DOMINOS Dynamic</h2>
#     <p style="font-size: 16px; max-width: 700px; margin: auto;">
#         faching the data from the dominos website
#     </p>
#     <hr style="width: 60%;">
# </div>

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://m.dominos.co.in/jfl-discovery-ui/en/web/menu-v2/6585R?&showSearchModal=false&scrollTo=209")
time.sleep(2)
quotes = driver.find_elements(By.TAG_NAME, "div")
for quote in quotes:
    print(quote.text)
driver.quit()
# Out:
# Domino's Pizza
# Veg Only
# Non Veg Only
# Sort by
# Veg Pizza
# Non-Veg Pizza
# Cheese Volcano
# Chicken Feast
# Pizza Mania
# Garlic Breads & Dips
# Beverages
# Desserts
# 5 Course Meal
# Love Loaded@299
# Chicken Burst
# No Onion No Garlic
# Cheese Burst Pizza
# 5 Course Lunch Feast
# Crazy Deals
# Tacos & Parcels
# Cheese Lava
# Sourdough @299
# Menu@99
# Lava Wednesday
# Veg Pizza
# Margherita
# Classic delight with 100% real mozzarella cheese.
# Rs.109
# RegularNew Hand Tossed
# Add +
# Farmhouse
# Delightful combination of onion, capsicum, tomato & grilled mushroom.
# Rs.259
# RegularNew Hand Tossed
# Add +
# Peppy Paneer
# Flavorful trio of juicy paneer, crisp capsicum with spicy red paprika.
# Rs.259
# RegularNew Hand Tossed
# Add +
# Veggie Paradise
# The awesome foursome! Golden corn, black olives, capsicum, red paprika.
# Rs.259
# RegularNew Hand Tossed
# Add +
# Indi Tandoori Paneer
# ...

# %% [markdown]
# <center><h2>THANKU</h2></center>
