# %% [markdown]
# <div style="text-align: center; padding: 20px:colour='red'">
#     <h1 style="color: white;">Vishal Sachdeva</h1>
#     <h2 style="color: orange;">Gyansetu API</h2>
#     <p style="font-size: 16px; max-width: 700px; margin: auto;">
#         faching the data from the Gyansetu website
#     </p>
#     <hr style="width: 60%;">
# </div>

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
url="https://gyansetu.codroidhub.com/api/feedbacks"
headers={
    "User Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36"
}
response = requests.get(url, headers = headers)
print(response)
print(response.content)
data=response.json()
print(type(data))
print(data[0])
main_data=data[0]
main_data.keys()
id_data=main_data["_id"]
print(len(id_data))
name_list = []
unique_id_list = []

for id in id_data:
    # print(saif)
    name_list.append(id[0])
    unique_id_list.append(id[0])
    
df = pd.DataFrame({
    "Name": name_list,
    "Unique_Id": unique_id_list
})
print(df)
df.to_csv("data/dynamic/Gyansetu_data.csv", index=False)
# Out:
# <Response [200]>
# ...

# %% [markdown]
# <center><h2>THANKU</h2></center>
