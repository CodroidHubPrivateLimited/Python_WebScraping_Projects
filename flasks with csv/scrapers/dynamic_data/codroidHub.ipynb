# %% [markdown]
# <div style="text-align: center; padding: 20px:colour='red'">
#     <h1 style="color: white;">Vishal Sachdeva</h1>
#     <h2 style="color: blue;">codroidhub API</h2>
#     <p style="font-size: 16px; max-width: 700px; margin: auto;">
#         faching the data from the cordroidhub website
#     </p>
#     <hr style="width: 60%;">
# </div>

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

url = "https://codroidhub.com/api/testimonials"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

print(type(response.content))

data = response.json()

main_data = data["testimonials"]

print(type(main_data))

id_list1 = []
name_list1 = []
role_list1 = []
company_list1 = []

for item in main_data:
    id_list1.append(item.get("id"))
    name_list1.append(item.get("name"))
    role_list1.append(item.get("role"))
    company_list1.append(item.get("company"))

df = pd.DataFrame({
    "id": id_list1,
    "name": name_list1,
    "role": role_list1,
    "company": company_list1
})

print(df)
df.to_csv("data/dynamic/codroidHub_data.csv", index=False)
# Out:
# <class 'bytes'>
# <class 'list'>
#       id              name                                               role  \
# 0   None            Sakshi                        Trainee | Digital Marketing
# 1   None     Drishti Gupta                   Trainee | MERN Stack Development
# 2   None            Trisha  Trainee | Data Analytics & Visualization with ...
# 3   None         Isha Rani  Trainee | Data Analytics & Visualization with ...
# 4   None       Tarun Kumar  Trainee | Large Language Models (LLMs) with Hu...
# 5   None      Tannu Sharma               Trainee | \tCorporate Communications
# 6   None            Ishika                      Trainee |Human Resources (HR)
# 7   None      Mahima Gupta        Trainee | AI & Machine Learning with Python
# 8   None              Neha  Trainee | Large Language Models (LLMs) with Hu...
# 9   None   Rasanpreet kaur  Trainee | Finance & Accounts with IT Applications
# 10  None       Sumit Singh        Trainee | AI & Machine Learning with Python
# ...

# %% [markdown]
# <center><h2>THANKU</h2><center>
