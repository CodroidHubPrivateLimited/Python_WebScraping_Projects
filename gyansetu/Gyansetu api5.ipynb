# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #667eea, #764ba2);
#     padding: 60px 20px;
#     text-align: center;
#     border-radius: 20px;
#     box-shadow: 0 20px 40px rgba(0,0,0,0.25);
#     font-family: 'Segoe UI', Helvetica, sans-serif;
#     color: white;
# ">
#
#   <h1 style="
#         font-size: 42px;
#         font-weight: 700;
#         letter-spacing: 1px;
#         margin-bottom: 20px;
#     ">
#         Gyansetu API Web Scraping
#     </h1>
#
#  <p style="
#         font-size: 18px;
#         opacity: 0.9;
#         margin-bottom: 30px;
#     ">
#         Extracting Real-Time Data using Python & API
#     </p>
#
#   <span style="
#         background: white;
#         color: #764ba2;
#         padding: 12px 30px;
#         border-radius: 50px;
#         font-weight: 600;
#         font-size: 18px;
#         box-shadow: 0 8px 20px rgba(0,0,0,0.15);
#         transition: 0.3s;
#     ">
#         Mansi Sharma
#     </span>
#
# </div>

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
url="https://gyansetu.codroidhub.com/api/universities"

# %%
headers = {"user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36"}

# %%
response = requests.get(url,headers= headers)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()

# %%
main_data=data["data"]

# %%
main_data[0].keys()
# Out:
# dict_keys(['_id', 'name', 'logo', 'description', 'coursesProvided', 'address', 'createdAt', 'updatedAt', '__v', 'registeredStudentCount'])

# %%
name_list = []
address_list =[]
registeredStudentCount =[]
logo =[]
for main in main_data:
    name_list.append(main["name"])
    address_list.append(main["address"])
    registeredStudentCount.append(main["registeredStudentCount"])
    logo.append(main["logo"])
df = pd.DataFrame({
    "name": name_list,
    "address": address_list,
    "registeredStudentCount":registeredStudentCount,
    "logo":logo
})
df
# Out:
#                             name            address  registeredStudentCount  \
# 0               Geeta University   Panipat, Haryana                      62
# 1  Ambala College of Engineering    Ambala, Haryana                       0
# 2              Panjab University  Chandigarh, India                       0
# 3                     SD College    Ambala, Haryana                       0
# 4          Chandigarh University  Chandigarh, India                       0
# 5                    CGC Landran  Chandigarh, India                       0
# 6                         JMIETI             Radaur                       0
#
#                                                 logo
# 0  https://tse2.mm.bing.net/th/id/OIP.x1zcVA__uJe...
# 1  https://www.ambalacollege.com/wp-content/uploa...
# 2  https://tse2.mm.bing.net/th/id/OIP.RZap6NytL5-...
# 3  https://moodle.sdcollegeambala.org/pluginfile....
# 4  https://tse4.mm.bing.net/th/id/OIP.mTr0MiAezQS...
# ...

# %% [markdown]
# <html>
# <head>
#     <title></title>
# </head>
# <body
# style="background: linear-gradient(to right, #74ebd5, #ACB6E5);
#     text-align: center;
#              font-family: Arial;
#              margin: 0;
#              padding-top: 150px;">
#
# <div style="background-color: white;
#                 display: inline-block;
#                 padding: 40px 60px;
#                 border-radius: 15px;
#                 box-shadow: 0 8px 20px rgba(0,0,0,0.2);">
#
#   <h1 style="color: #2c3e50; font-size: 42px; margin-bottom: 10px;">
#             Thank You!
#         </h1>
#
# <p style="font-size: 22px; color: #6c5ce7; font-weight: bold;">
#             Mansi Sharma
#         </p>
#
#   </div>
#
# </body>
# </html>
