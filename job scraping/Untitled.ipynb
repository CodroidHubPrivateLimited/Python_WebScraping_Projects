# %%
from flask import Flask, render_template

app = Flask(__name__)

@app.route("/")
def index():
  return render_template("index.html")

app.ru
n()

# %%
# %tb
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 57
#      53     result = {"dataframes": dataframes, "user": user}
#      54     return json.dumps(result, ensure_ascii=False)
# ---> 57 get_dataframes()
#
# Cell In[6], line 51, in get_dataframes()
#      41 user = getpass.getuser()
#      42 values = get_ipython().run_line_magic('who_ls', '')
#      43 dataframes = [
#      44     {
#      45         "name": var,
#      46         "type": type(eval(var)).__name__,
#      47         "hash": dataframe_hash(var),
#      48         "cols": dataframe_columns(var),
#      49         "dtypesStr": dtypes_str(var),
#      50     }
# ---> 51     for var in values if is_data_frame(var)
#      52 ]
#      53 result = {"dataframes": dataframes, "user": user}
#      54 return json.dumps(result, ensure_ascii=False)
#
# Cell In[6], line 17, in is_data_frame(v)
# ...

# %%
# !pip install flask
# Out:
# ...
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# ...
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# ...
