# %% [markdown]
# <div style="text-align: center; padding: 20px:colour='red'">
#     <h1 style="color: rgb(249, 249, 246);">Vishal Sachdeva</h1>
#     <h2 style="color: rgb(251, 255, 9);">SWIGGY Dynamic</h2>
#     <p style="font-size: 16px; max-width: 700px; margin: auto;">
#         faching the data from the swiggy website
#     </p>
#     <hr style="width: 60%;">
# </div>

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
driver2 = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver2.get("https://www.swiggy.com/collections/83637?collection_id=83637&search_context=burger&tags=layout_CCS_Burger&type=rcv2")
time.sleep(2)
quotes2 = driver2.find_elements(By.TAG_NAME, "div")
for quote in quotes2:
    print(quote.text)
driver2.quit()
# Out:
# Other
# 0
# Cart
# Sign In
# Help
# Offers
# NEW
# Search
# Swiggy Corporate
# Burger
# Satisfy your cravings with these fresh and flavoursome burgers.
# Filter
# Sort By
# 10 Mins Delivery
# Restaurants to explore
# ITEMS AT ₹99
# Sandburgs
# 4.6 • 25-30 mins
# Burgers, American, Salads
# Sector -70
# ITEMS AT ₹59
# Burger King
# 4.5 • 30-35 mins
# Burgers, American
# Chandigarh
# 50% OFF
# Popeyes
# 4.6 • 25-30 mins
# Burgers, Fast Food, Rolls & Wraps
# South Mohali
# 50% OFF
# KFC
# 4.4 • 25-30 mins
# Burgers, Fast Food, Rolls & Wraps
# Sector 67 Mohali
# 50% OFF UPTO ₹100
# Plateplay
# 4.4 • 30-35 mins
# Continental, Asian, Thai, sandwich, pizza, Middle Eastern, Burger, Chinese, Beverages
# South Mohali
# ITEMS AT ₹49
# McDonald's
# 4.4 • 20-25 mins
# American, Fast Food
# Airport Road
# ITEMS AT ₹99
# Wow! China
# 3.9 • 40-45 mins
# Chinese, Asian, fastfood, Beverages, Snacks
# Mohali Walk
# Other
# 0
# Cart
# Sign In
# Help
# Offers
# NEW
# Search
# Swiggy Corporate
# Burger
# ...

# %% [markdown]
# <center><h2>THANKU</h2><center>
