# %% [markdown]
# <div style="text-align: center; padding: 20px:colour='red'">
#     <h1 style="color: rgb(249, 249, 246);">Vishal Sachdeva</h1>
#     <h2 style="color: red;">Zomato Dynamic</h2>
#     <p style="font-size: 16px; max-width: 700px; margin: auto;">
#         faching the data from the Zomato website
#     </p>
#     <hr style="width: 60%;">
# </div>

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
driver2 = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver2.get("https://www.zomato.com/chandigarh/restaurants")
time.sleep(2)
quotes2 = driver2.find_elements(By.TAG_NAME, "a")
for quote in quotes2:
    print(quote.text)
driver2.quit()
# Out:
# Log in
# Sign up
# Home
# /
# India
# /
# Chandigarh Restaurants
# All collections in Chandigarh
# New in town
# 5 Places
# Top trending spots
# 36 Places
# Best luxury dining places
# 23 Places
# Insta-worthy spots
# 11 Places
#
#
#
#
#
# Promoted
# Flat 15% OFF
# Velora - Elysian Bar
# New
# North Indian, Asian
# ₹2,000 for two
# Sector 7, Chandigarh
# 2.6 km
# Promoted
# Flat 10% OFF
# TAO Cafe Kitchen Bar
# 4.5
# Asian, North Indian, Continental
# ₹2,000 for two
# Sector 26, Chandigarh
# 3.2 km
# Promoted
# Flat 10% OFF
# Parampara Restaurant & Bar
# 4.3
# North Indian, Mughlai, Biryani, Desserts, Shake, Beverages
# ₹1,200 for two
# Sector 35, Chandigarh
# 2.2 km
# Promoted
# Rhapsody
# 4.5
# North Indian, Chinese, Biryani, Coffee, Continental, Italian, Burger, Beverages
# ₹2,000 for two
# Sector 17, Chandigarh
# 1.3 km
# Promoted
# Cafe Well Being
# 4.5
# North Indian, Sandwich, Pizza, Fast Food, Desserts, Shake, Beverages
# ₹750 for two
# Sector 22, Chandigarh
# 1.2 km
# Promoted
# Sector 7 Social
# 4.4
# North Indian, Chinese, Biryani, Pasta, Burger, Pizza, Momos, Beverages
# ₹1,500 for two
# Sector 7, Chandigarh
# 2.6 km
# Promoted
# Flat 15% OFF
# Anardana
# 4.9
# North Indian, Italian, Chinese, Modern Indian, Mughlai, Biryani, Desserts, Beverages
# ₹1,800 for two
# Chandigarh Industrial Area, Chandigarh
# 4 km
# Promoted
# Flat 10% OFF
# Beyon
# 4.1
# Asian, European, Italian, North Indian, Seafood, Desserts, Coffee, Beverages
# ₹3,400 for two
# Sector 26, Chandigarh
# 3.3 km
# Promoted
# Flat 10% OFF
# Meliaa - A Fine Cuisine Bar
# 4.5
# Turkish, Mediterranean, Greek, Desserts
# ₹1,800 for two
# Sector 8, Chandigarh
# 1.7 km
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Who We Are
# Blog
# Work With Us
# Investor Relations
# Report Fraud
# Press Kit
# Contact Us
# Zomato
# Blinkit
# District
# Feeding India
# Hyperpure
# Zomato Live
# Zomaland
# Weather Union
# Partner With Us
# Apps For You
# Privacy
# Security
# Terms

# %% [markdown]
# <marquee><h2 style="color: red;">Thanku</h2></marquee>>
